# %%
import requests
import math
import os
import csv
import numpy as np
import pandas as pd

# %% [markdown]
# ## Functions

# %%
trip
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-2fe620c859db> in <module>
# ----> 1 trip
#
# NameError: name 'trip' is not defined

# %%
trip = all_trips[0]['trips'][0]
trip
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-88ceb7471bcb> in <module>
# ----> 1 trip = all_trips[0]['trips'][0]
#       2 trip
#
# NameError: name 'all_trips' is not defined

# %%
all_trips[0]['trips'][0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-eff9568160bd> in <module>
# ----> 1 all_trips[0]['trips'][0]
#
# NameError: name 'all_trips' is not defined

# %%
trip['vehicle']['model']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-f0001356de98> in <module>
# ----> 1 trip['vehicle']['model']
#
# NameError: name 'trip' is not defined

# %%
def getRow(trip):
    '''
    Flattens a BlaBlaCar trip object into the plain list we want to upload to CARTO
    '''
    return {
            'url'         : trip['link'], #fixed
            'from_lat'    : trip['waypoints'][0]['place']['latitude'], #fixed
            'from_lon'    : trip['waypoints'][0]['place']['longitude'], #fixed
            'to_lat'      : trip['waypoints'][1]['place']['latitude'], #fixed
            'to_lon'      : trip['waypoints'][1]['place']['longitude'], #fixed
            'car_maker'   : trip['vehicle']['make'] if 'vehicle' in trip else '', #fixed
            'car_model'   : trip['vehicle']['model'] if 'vehicle' in trip else '' , #fixed
            'dep_date'    : trip['waypoints'][0]['date_time'], #fixed
            'arive_date'  : trip['waypoints'][1]['date_time'], #fixed
            'distance_m'  : trip['distance_in_meters'], #fixed
            'duration_s'  : trip['duration_in_seconds'], #fixed
            'price'       : trip['price']['amount'], #fixed
            'currency'    : trip['price']['currency'], #fixed
            }

# %% [markdown]
# Comfort and # of seats are missing. There are null values in the vehicle columns!

# %%
def getTrips(city):  #Berlin-Dresden
    '''
    Iterates over the BlaBlaCar /trips/ endpoint to retrieve all the pages
    '''
    trips = []
    page = 1
    
    URL = "https://public-api.blablacar.com/api/v3/trips?from_coordinate=52.520008,13.404954&to_coordinate=51.050407,13.737262&locale=de-DE&currency=EUR&key=xcP0TPgR57BBbCUxjCI8G9S36kRVVnaO"
    KEY = os.getenv('BLABLACAR_API')
    CUR = "EUR"
    HEADERS = {
        'Content-Type': "application/json",
        'Cache-Control': "no-cache"
    }
    QS_BASE = {"key": KEY,"cur": CUR, "limit": 100} 

    querystring = dict( { 'page' : page, "fn": city, }, **QS_BASE)
    response = requests.request("GET", URL, headers=HEADERS, params=querystring)
    rj = response.json()

    while 'trips' in rj:
        #print('  Got page {}'.format(page))
        trips.extend(rj['trips'])
        page = page + 1

        querystring = dict( { 'page' : page, "fn": city }, **QS_BASE)
        response = requests.request("GET", URL, headers=HEADERS, params=querystring)
        rj = response.json()
        
    return trips

# %% [markdown]
# ## Process cities
#
# Process a list of cities to get all the trips and generates as a result a CSV ready to be used at CARTO

# %%
cities = ['Berlin']

# %%
all_trips = []

for city in cities:
    print('Getting the trips from BlaBlaCar API from {}...'.format(city))
    trips = getTrips(city)        
    print('{} trips retreived'.format(len(trips)))        
    all_trips.append({ 'city':city,'trips': trips})
    print('')
# Out:
# Getting the trips from BlaBlaCar API from Berlin...

# %%
print(all_trips)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# Once get all the trips, save them into a single CSV file

# %%
filename = 'blablatripsDE2.csv'
print('Generating {}...'.format(filename))
with open(filename, 'w', newline='') as csvfile:
    fieldnames = [
        'city', 'url', 'from_lat', 'from_lon', 'to_lat', 'to_lon', 'car_maker', 'car_model', 
        'dep_date', 'arive_date', 'distance_m', 'duration_s', 'price', 'currency'
    ]
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    for group in all_trips:
        city = group['city']
        trips = group['trips']
        try:
            for trip in trips:
                row = getRow(trip)
                writer.writerow(dict({'city':city},**row))
        except KeyError as e:
            print(e)
            print(trip)

print('Done!')
# Out:
# Generating blablatripsDE2.csv...
# Done!

# %%
df = pd.read_csv('blablatripsDE2.csv')

# %%
df.shape
# Out:
# (11080, 14)

# %%
df.head(50)
# Out:
#       city                                                url   from_lat  \
# 0   Berlin  https://www.blablacar.de/trip?source=CARPOOLIN...  52.386210
# 1   Berlin  https://www.blablacar.de/trip?source=CARPOOLIN...  52.520812
# 2   Berlin  https://www.blablacar.de/trip?source=CARPOOLIN...  52.558459
# 3   Berlin  https://www.blablacar.de/trip?source=CARPOOLIN...  52.392216
# 4   Berlin  https://www.blablacar.de/trip?source=CARPOOLIN...  52.521981
# 5   Berlin  https://www.blablacar.de/trip?source=CARPOOLIN...  52.478608
# 6   Berlin  https://www.blablacar.de/trip?source=CARPOOLIN...  52.364441
# 7   Berlin  https://www.blablacar.de/trip?source=CARPOOLIN...  52.466690
# 8   Berlin  https://www.blablacar.de/trip?source=CARPOOLIN...  52.507300
# 9   Berlin  https://www.blablacar.de/trip?source=CARPOOLIN...  52.435094
# 10  Berlin  https://www.blablacar.de/trip?source=CARPOOLIN...  52.386210
# 11  Berlin  https://www.blablacar.de/trip?source=CARPOOLIN...  52.520812
# 12  Berlin  https://www.blablacar.de/trip?source=CARPOOLIN...  52.558459
# 13  Berlin  https://www.blablacar.de/trip?source=CARPOOLIN...  52.392216
# 14  Berlin  https://www.blablacar.de/trip?source=CARPOOLIN...  52.521981
# 15  Berlin  https://www.blablacar.de/trip?source=CARPOOLIN...  52.478608
# 16  Berlin  https://www.blablacar.de/trip?source=CARPOOLIN...  52.364441
# 17  Berlin  https://www.blablacar.de/trip?source=CARPOOLIN...  52.466690
# 18  Berlin  https://www.blablacar.de/trip?source=CARPOOLIN...  52.507300
# 19  Berlin  https://www.blablacar.de/trip?source=CARPOOLIN...  52.435094
# 20  Berlin  https://www.blablacar.de/trip?source=CARPOOLIN...  52.386210
# 21  Berlin  https://www.blablacar.de/trip?source=CARPOOLIN...  52.520812
# 22  Berlin  https://www.blablacar.de/trip?source=CARPOOLIN...  52.558459
# 23  Berlin  https://www.blablacar.de/trip?source=CARPOOLIN...  52.392216
# 24  Berlin  https://www.blablacar.de/trip?source=CARPOOLIN...  52.521981
# 25  Berlin  https://www.blablacar.de/trip?source=CARPOOLIN...  52.478608
# 26  Berlin  https://www.blablacar.de/trip?source=CARPOOLIN...  52.364441
# 27  Berlin  https://www.blablacar.de/trip?source=CARPOOLIN...  52.466690
# 28  Berlin  https://www.blablacar.de/trip?source=CARPOOLIN...  52.507300
# 29  Berlin  https://www.blablacar.de/trip?source=CARPOOLIN...  52.435094
# 30  Berlin  https://www.blablacar.de/trip?source=CARPOOLIN...  52.386210
# 31  Berlin  https://www.blablacar.de/trip?source=CARPOOLIN...  52.520812
# 32  Berlin  https://www.blablacar.de/trip?source=CARPOOLIN...  52.558459
# 33  Berlin  https://www.blablacar.de/trip?source=CARPOOLIN...  52.392216
# 34  Berlin  https://www.blablacar.de/trip?source=CARPOOLIN...  52.521981
# 35  Berlin  https://www.blablacar.de/trip?source=CARPOOLIN...  52.478608
# 36  Berlin  https://www.blablacar.de/trip?source=CARPOOLIN...  52.364441
# 37  Berlin  https://www.blablacar.de/trip?source=CARPOOLIN...  52.466690
# 38  Berlin  https://www.blablacar.de/trip?source=CARPOOLIN...  52.507300
# 39  Berlin  https://www.blablacar.de/trip?source=CARPOOLIN...  52.435094
# 40  Berlin  https://www.blablacar.de/trip?source=CARPOOLIN...  52.386210
# 41  Berlin  https://www.blablacar.de/trip?source=CARPOOLIN...  52.520812
# 42  Berlin  https://www.blablacar.de/trip?source=CARPOOLIN...  52.558459
# 43  Berlin  https://www.blablacar.de/trip?source=CARPOOLIN...  52.392216
# 44  Berlin  https://www.blablacar.de/trip?source=CARPOOLIN...  52.521981
# 45  Berlin  https://www.blablacar.de/trip?source=CARPOOLIN...  52.478608
# 46  Berlin  https://www.blablacar.de/trip?source=CARPOOLIN...  52.364441
# 47  Berlin  https://www.blablacar.de/trip?source=CARPOOLIN...  52.466690
# 48  Berlin  https://www.blablacar.de/trip?source=CARPOOLIN...  52.507300
# 49  Berlin  https://www.blablacar.de/trip?source=CARPOOLIN...  52.435094
#
#      from_lon     to_lat     to_lon   car_maker       car_model  \
# 0   13.489772  51.084584  13.693945       SKODA           FABIA
# 1   13.699738  51.065486  13.740971         NaN             NaN
# 2   13.778052  50.993360  13.850380       DACIA  DOKKER STEPWAY
# 3   13.790521  51.056018  13.708131         NaN             NaN
# 4   13.413306  51.065486  13.740971         BMW        3 SERIES
# 5   13.320768  51.040502  13.731419         NaN             NaN
# 6   13.509853  51.085411  13.692314  VOLKSWAGEN          PASSAT
# 7   13.488654  51.084884  13.694924         NaN             NaN
# 8   13.280596  51.040502  13.731419        FORD          FUSION
# 9   13.541023  51.042667  13.796564        FORD           FOCUS
# 10  13.489772  51.084584  13.693945       SKODA           FABIA
# 11  13.699738  51.065486  13.740971         NaN             NaN
# 12  13.778052  50.993360  13.850380       DACIA  DOKKER STEPWAY
# 13  13.790521  51.056018  13.708131         NaN             NaN
# 14  13.413306  51.065486  13.740971         BMW        3 SERIES
# 15  13.320768  51.040502  13.731419         NaN             NaN
# 16  13.509853  51.085411  13.692314  VOLKSWAGEN          PASSAT
# 17  13.488654  51.084884  13.694924         NaN             NaN
# 18  13.280596  51.040502  13.731419        FORD          FUSION
# 19  13.541023  51.042667  13.796564        FORD           FOCUS
# 20  13.489772  51.084584  13.693945       SKODA           FABIA
# 21  13.699738  51.065486  13.740971         NaN             NaN
# 22  13.778052  50.993360  13.850380       DACIA  DOKKER STEPWAY
# 23  13.790521  51.056018  13.708131         NaN             NaN
# 24  13.413306  51.065486  13.740971         BMW        3 SERIES
